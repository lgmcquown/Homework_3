# %%
import pdb

# %%
lines = [line.rstrip('/n') for line in open('elelib.std')]

# %%
Eledict = {}

# %%
#third function: ParseElement('file')
Number_of_lines = len(lines)
line_number = 0
while line_number < Number_of_lines:
    
#First function: parse each element 
    ElementData = lines[line_number].split()
    line_number += 1
    Symbol = ElementData[0] 
    Eledict[Symbol] = {"MM" : ElementData[1], "Z" : ElementData[2], "rho" : ElementData[3]}
    NumIsos = ElementData[4]

    
#Second function
    Eledict[Symbol]["IsoList"] = {}
    for isotope in range(int(NumIsos)):
        IsoData = lines[line_number].split()
        line_number += 1
        Eledict[Symbol]["IsoList"][IsoData[0]] = IsoData[1]

# %%
Eledict
# Out:
# {'ag': {'IsoList': {'107': '0.518400E+02', '109': '0.481600E+02'},
#   'MM': '0.107868E+03',
#   'Z': '47',
#   'rho': '0.105000E+02'},
#  'al': {'IsoList': {'27': '0.100000E+03'},
#   'MM': '0.269815E+02',
#   'Z': '13',
#   'rho': '0.270000E+01'},
#  'ar': {'IsoList': {'36': '0.337000E+00',
#    '38': '0.630000E-01',
#    '40': '0.996000E+02'},
#   'MM': '0.399480E+02',
#   'Z': '18',
#   'rho': '0.178400E-02'},
#  'as': {'IsoList': {'75': '0.100000E+03'},
#   'MM': '0.749216E+02',
#   'Z': '33',
#   'rho': '0.572000E+01'},
#  'au': {'IsoList': {'197': '0.100000E+03'},
#   'MM': '0.196967E+03',
#   'Z': '79',
#   'rho': '0.193000E+02'},
#  'b': {'IsoList': {'10': '0.199000E+02', '11': '0.801000E+02'},
#   'MM': '0.108100E+02',
#   'Z': '5',
#   'rho': '0.234000E+01'},
#  'ba': {'IsoList': {'130': '0.106000E+00',
#    '132': '0.101000E+00',
#    '134': '0.242000E+01',
#    '135': '0.659300E+01',
#    '136': '0.785000E+01',
#    '137': '0.112300E+02',
#    '138': '0.717000E+02'},
#   'MM': '0.137330E+03',
#   'Z': '56',
#   'rho': '0.350000E+01'},
#  'be': {'IsoList': {'9': '0.100000E+03'},
#   'MM': '0.901218E+01',
#   'Z': '4',
#   'rho': '0.185000E+01'},
#  'bi': {'IsoList': {'209': '0.100000E+03'},
#   'MM': '0.208980E+03',
#   'Z': '83',
#   'rho': '0.980000E+01'},
#  'br': {'IsoList': {'79': '0.506900E+02', '81': '0.493100E+02'},
#   'MM': '0.799040E+02',
#   'Z': '35',
#   'rho': '0.312000E+01'},
#  'c': {'IsoList': {'12': '0.988920E+02', '13': '0.110800E+01'},
#   'MM': '0.120110E+02',
#   'Z': '6',
#   'rho': '0.262000E+01'},
#  'ca': {'IsoList': {'40': '0.969410E+02',
#    '42': '0.647000E+00',
#    '43': '0.135000E+00',
#    '44': '0.208600E+01',
#    '46': '0.400000E-02',
#    '48': '0.187000E+00'},
#   'MM': '0.400800E+02',
#   'Z': '20',
#   'rho': '0.155000E+01'},
#  'cd': {'IsoList': {'106': '0.125000E+01',
#    '108': '0.890000E+00',
#    '110': '0.124900E+02',
#    '111': '0.128000E+02',
#    '112': '0.241300E+02',
#    '113': '0.122200E+02',
#    '114': '0.287300E+02',
#    '116': '0.749000E+01'},
#   'MM': '0.112410E+03',
#   'Z': '48',
#   'rho': '0.865000E+01'},
#  'ce': {'IsoList': {'136': '0.190000E+00',
#    '138': '0.250000E+00',
#    '140': '0.884300E+02',
#    '142': '0.111300E+02'},
#   'MM': '0.140120E+03',
#   'Z': '58',
#   'rho': '0.678000E+01'},
#  'cl': {'IsoList': {'35': '0.757700E+02', '37': '0.242300E+02'},
#   'MM': '0.354530E+02',
#   'Z': '17',
#   'rho': '0.317000E-02'},
#  'co': {'IsoList': {'59': '0.100000E+03'},
#   'MM': '0.589332E+02',
#   'Z': '27',
#   'rho': '0.890000E+01'},
#  'cr': {'IsoList': {'50': '0.434500E+01',
#    '52': '0.837900E+02',
#    '53': '0.950000E+01',
#    '54': '0.236500E+01'},
#   'MM': '0.519960E+02',
#   'Z': '24',
#   'rho': '0.719000E+01'},
#  'cs': {'IsoList': {'133': '0.100000E+03'},
#   'MM': '0.132905E+03',
#   'Z': '55',
#   'rho': '0.187000E+01'},
#  'cu': {'IsoList': {'63': '0.691700E+02', '65': '0.308300E+02'},
#   'MM': '0.635460E+02',
#   'Z': '29',
#   'rho': '0.896000E+01'},
#  'dy': {'IsoList': {'156': '0.600000E-01',
#    '158': '0.100000E+00',
#    '160': '0.234000E+01',
#    '161': '0.189000E+02',
#    '162': '0.255000E+02',
#    '163': '0.249000E+02',
#    '164': '0.282000E+02'},
#   'MM': '0.162500E+03',
#   'Z': '66',
#   'rho': '0.854000E+01'},
#  'er': {'IsoList': {'162': '0.140000E+00',
#    '164': '0.161000E+01',
#    '166': '0.336000E+02',
#    '167': '0.229500E+02',
#    '168': '0.268000E+02',
#    '170': '0.149000E+02'},
#   'MM': '0.167260E+03',
#   'Z': '68',
#   'rho': '0.905000E+01'},
#  'eu': {'IsoList': {'151': '0.478000E+02', '153': '0.522000E+02'},
#   'MM': '0.151960E+03',
#   'Z': '63',
#   'rho': '0.526000E+01'},
#  'f': {'IsoList': {'19': '0.100000E+03'},
#   'MM': '0.189984E+02',
#   'Z': '9',
#   'rho': '0.169600E-02'},
#  'fe': {'IsoList': {'54': '0.590000E+01',
#    '56': '0.917200E+02',
#    '57': '0.210000E+01',
#    '58': '0.280000E+00'},
#   'MM': '0.558470E+02',
#   'Z': '26',
#   'rho': '0.786000E+01'},
#  'ga': {'IsoList': {'69': '0.601100E+02', '71': '0.398900E+02'},
#   'MM': '0.697200E+02',
#   'Z': '31',
#   'rho': '0.591000E+01'},
#  'gd': {'IsoList': {'152': '0.200000E+00',
#    '154': '0.218000E+01',
#    '155': '0.148000E+02',
#    '156': '0.204700E+02',
#    '157': '0.156500E+02',
#    '158': '0.248400E+02',
#    '160': '0.218600E+02'},
#   'MM': '0.157250E+03',
#   'Z': '64',
#   'rho': '0.789000E+01'},
#  'ge': {'IsoList': {'70': '0.205000E+02',
#    '72': '0.274000E+02',
#    '73': '0.780000E+01',
#    '74': '0.365000E+02',
#    '76': '0.776000E+01'},
#   'MM': '0.725900E+02',
#   'Z': '32',
#   'rho': '0.532000E+01'},
#  'h': {'IsoList': {'1': '0.999850E+02', '2': '0.150000E-01'},
#   'MM': '0.100790E+01',
#   'Z': '1',
#   'rho': '0.899000E-04'},
#  'he': {'IsoList': {'3': '0.100000E-03', '4': '0.100000E+03'},
#   'MM': '0.400260E+01',
#   'Z': '2',
#   'rho': '0.178700E-03'},
#  'hf': {'IsoList': {'174': '0.162000E+00',
#    '176': '0.520600E+01',
#    '177': '0.186060E+02',
#    '178': '0.272970E+02',
#    '179': '0.136290E+02',
#    '180': '0.351000E+02'},
#   'MM': '0.178490E+03',
#   'Z': '72',
#   'rho': '0.131000E+02'},
#  'hg': {'IsoList': {'196': '0.150000E+00',
#    '198': '0.100000E+02',
#    '199': '0.169000E+02',
#    '200': '0.231000E+02',
#    '201': '0.132000E+02',
#    '202': '0.298000E+02',
#    '204': '0.685000E+01'},
#   'MM': '0.200590E+03',
#   'Z': '80',
#   'rho': '0.135300E+02'},
#  'ho': {'IsoList': {'165': '0.100000E+03'},
#   'MM': '0.164930E+03',
#   'Z': '67',
#   'rho': '0.880000E+01'},
#  'i': {'IsoList': {'127': '0.100000E+03'},
#   'MM': '0.126905E+03',
#   'Z': '53',
#   'rho': '0.492000E+01'},
#  'in': {'IsoList': {'113': '0.428000E+01', '115': '0.957200E+02'},
#   'MM': '0.114820E+03',
#   'Z': '49',
#   'rho': '0.731000E+01'},
#  'ir': {'IsoList': {'191': '0.373000E+02', '193': '0.627000E+02'},
#   'MM': '0.192220E+03',
#   'Z': '77',
#   'rho': '0.225000E+02'},
#  'k': {'IsoList': {'39': '0.932580E+02', '41': '0.674000E+01'},
#   'MM': '0.390983E+02',
#   'Z': '19',
#   'rho': '0.860000E+00'},
#  'kr': {'IsoList': {'78': '0.350000E+00',
#    '80': '0.225000E+01',
#    '82': '0.116000E+02',
#    '83': '0.115000E+02',
#    '84': '0.570000E+02',
#    '86': '0.173000E+02'},
#   'MM': '0.838000E+02',
#   'Z': '36',
#   'rho': '0.374000E-02'},
#  'la': {'IsoList': {'138': '0.900000E-01', '139': '0.999100E+02'},
#   'MM': '0.138906E+03',
#   'Z': '57',
#   'rho': '0.670000E+01'},
#  'li': {'IsoList': {'6': '0.752000E+01', '7': '0.924800E+02'},
#   'MM': '0.694100E+01',
#   'Z': '3',
#   'rho': '0.530000E+00'},
#  'lu': {'IsoList': {'175': '0.974000E+02', '176': '0.260000E+01'},
#   'MM': '0.174967E+03',
#   'Z': '71',
#   'rho': '0.984000E+01'},
#  'mg': {'IsoList': {'24': '0.789900E+02',
#    '25': '0.100000E+02',
#    '26': '0.110100E+02'},
#   'MM': '0.243050E+02',
#   'Z': '12',
#   'rho': '0.174000E+01'},
#  'mn': {'IsoList': {'55': '0.100000E+03'},
#   'MM': '0.549380E+02',
#   'Z': '25',
#   'rho': '0.743000E+01'},
#  'mo': {'IsoList': {'100': '0.963000E+01',
#    '92': '0.148400E+02',
#    '94': '0.925000E+01',
#    '95': '0.159200E+02',
#    '96': '0.166800E+02',
#    '97': '0.955000E+01',
#    '98': '0.241300E+02'},
#   'MM': '0.959400E+02',
#   'Z': '42',
#   'rho': '0.102000E+02'},
#  'n': {'IsoList': {'14': '0.996340E+02', '15': '0.366000E+00'},
#   'MM': '0.140067E+02',
#   'Z': '7',
#   'rho': '0.125100E-02'},
#  'na': {'IsoList': {'23': '0.100000E+03'},
#   'MM': '0.229898E+02',
#   'Z': '11',
#   'rho': '0.970000E+00'},
#  'nb': {'IsoList': {'93': '0.100000E+03'},
#   'MM': '0.929064E+02',
#   'Z': '41',
#   'rho': '0.855000E+01'},
#  'nd': {'IsoList': {'142': '0.271300E+02',
#    '143': '0.121800E+02',
#    '144': '0.238000E+02',
#    '145': '0.830000E+01',
#    '146': '0.171900E+02',
#    '148': '0.576000E+01',
#    '150': '0.564000E+01'},
#   'MM': '0.144240E+03',
#   'Z': '60',
#   'rho': '0.700000E+01'},
#  'ne': {'IsoList': {'20': '0.904800E+02',
#    '21': '0.270000E+00',
#    '22': '0.929000E+01'},
#   'MM': '0.201790E+02',
#   'Z': '10',
#   'rho': '0.901000E-03'},
#  'ni': {'IsoList': {'58': '0.682700E+02',
#    '60': '0.261000E+02',
#    '61': '0.113000E+01',
#    '62': '0.359000E+01',
#    '64': '0.910000E+00'},
#   'MM': '0.587000E+02',
#   'Z': '28',
#   'rho': '0.890000E+01'},
#  'o': {'IsoList': {'16': '0.997590E+02',
#    '17': '0.370000E-01',
#    '18': '0.204000E+00'},
#   'MM': '0.159994E+02',
#   'Z': '8',
#   'rho': '0.142900E-02'},
#  'os': {'IsoList': {'184': '0.200000E-01',
#    '186': '0.158000E+01',
#    '187': '0.160000E+01',
#    '188': '0.133000E+02',
#    '189': '0.161000E+02',
#    '190': '0.264000E+02',
#    '192': '0.410000E+02'},
#   'MM': '0.190200E+03',
#   'Z': '76',
#   'rho': '0.224000E+02'},
#  'p': {'IsoList': {'31': '0.100000E+03'},
#   'MM': '0.309738E+02',
#   'Z': '15',
#   'rho': '0.182000E+01'},
#  'pb': {'IsoList': {'204': '0.140000E+01',
#    '206': '0.241000E+02',
#    '207': '0.221000E+02',
#    '208': '0.524000E+02'},
#   'MM': '0.207200E+03',
#   'Z': '82',
#   'rho': '0.114000E+02'},
#  'pd': {'IsoList': {'102': '0.102000E+01',
#    '104': '0.111400E+02',
#    '105': '0.223300E+02',
#    '106': '0.273300E+02',
#    '108': '0.264600E+02',
#    '110': '0.117200E+02'},
#   'MM': '0.106400E+03',
#   'Z': '46',
#   'rho': '0.120000E+02'},
#  'pr': {'IsoList': {'141': '0.100000E+03'},
#   'MM': '0.140907E+03',
#   'Z': '59',
#   'rho': '0.677000E+01'},
#  'pt': {'IsoList': {'190': '0.100000E-01',
#    '192': '0.790000E+00',
#    '194': '0.329000E+02',
#    '195': '0.338000E+02',
#    '196': '0.253000E+02',
#    '198': '0.720000E+01'},
#   'MM': '0.195090E+03',
#   'Z': '78',
#   'rho': '0.214000E+02'},
#  'rb': {'IsoList': {'85': '0.721600E+02', '87': '0.278400E+02'},
#   'MM': '0.854678E+02',
#   'Z': '37',
#   'rho': '0.153000E+01'},
#  're': {'IsoList': {'185': '0.374000E+02', '187': '0.626000E+02'},
#   'MM': '0.186207E+03',
#   'Z': '75',
#   'rho': '0.210000E+02'},
#  'rh': {'IsoList': {'103': '0.100000E+03'},
#   'MM': '0.102906E+03',
#   'Z': '45',
#   'rho': '0.124000E+02'},
#  'ru': {'IsoList': {'100': '0.126000E+02',
#    '101': '0.171000E+02',
#    '102': '0.316000E+02',
#    '104': '0.186000E+02',
#    '96': '0.554000E+01',
#    '98': '0.186000E+01',
#    '99': '0.127000E+02'},
#   'MM': '0.101070E+03',
#   'Z': '44',
#   'rho': '0.122000E+02'},
#  's': {'IsoList': {'32': '0.950200E+02',
#    '33': '0.750000E+00',
#    '34': '0.421000E+01',
#    '36': '0.200000E-01'},
#   'MM': '0.320600E+02',
#   'Z': '16',
#   'rho': '0.207000E+01'},
#  'sb': {'IsoList': {'121': '0.574000E+02', '123': '0.426000E+02'},
#   'MM': '0.121750E+03',
#   'Z': '51',
#   'rho': '0.668000E+01'},
#  'sc': {'IsoList': {'45': '0.100000E+03'},
#   'MM': '0.449559E+02',
#   'Z': '21',
#   'rho': '0.300000E+01'},
#  'se': {'IsoList': {'74': '0.900000E+00',
#    '76': '0.910000E+01',
#    '77': '0.760000E+01',
#    '78': '0.236000E+02',
#    '80': '0.499000E+02',
#    '82': '0.890000E+01'},
#   'MM': '0.789600E+02',
#   'Z': '34',
#   'rho': '0.480000E+01'},
#  'si': {'IsoList': {'28': '0.922300E+02',
#    '29': '0.467000E+01',
#    '30': '0.310000E+01'},
#   'MM': '0.280855E+02',
#   'Z': '14',
#   'rho': '0.233000E+01'},
#  'sm': {'IsoList': {'144': '0.310000E+01',
#    '147': '0.150000E+02',
#    '148': '0.113000E+02',
#    '149': '0.138000E+02',
#    '150': '0.740000E+01',
#    '152': '0.267000E+02',
#    '154': '0.227000E+02'},
#   'MM': '0.150400E+03',
#   'Z': '62',
#   'rho': '0.754000E+01'},
#  'sn': {'IsoList': {'112': '0.970000E+00',
#    '114': '0.650000E+00',
#    '115': '0.360000E+00',
#    '116': '0.145300E+02',
#    '117': '0.768000E+01',
#    '118': '0.242200E+02',
#    '119': '0.858000E+01',
#    '120': '0.325900E+02',
#    '122': '0.463000E+01',
#    '124': '0.579000E+01'},
#   'MM': '0.118690E+03',
#   'Z': '50',
#   'rho': '0.730000E+01'},
#  'sr': {'IsoList': {'84': '0.560000E+00',
#    '86': '0.986000E+01',
#    '87': '0.700000E+01',
#    '88': '0.825800E+02'},
#   'MM': '0.876200E+02',
#   'Z': '38',
#   'rho': '0.260000E+01'},
#  'ta': {'IsoList': {'181': '0.100000E+03'},
#   'MM': '0.180948E+03',
#   'Z': '73',
#   'rho': '0.166000E+02'},
#  'tb': {'IsoList': {'159': '0.100000E+03'},
#   'MM': '0.158925E+03',
#   'Z': '65',
#   'rho': '0.827000E+01'},
#  'te': {'IsoList': {'120': '0.950000E-01',
#    '122': '0.259000E+01',
#    '123': '0.905000E+00',
#    '124': '0.479000E+01',
#    '125': '0.712000E+01',
#    '126': '0.189300E+02',
#    '128': '0.317000E+02',
#    '130': '0.338700E+02'},
#   'MM': '0.127600E+03',
#   'Z': '52',
#   'rho': '0.624000E+01'},
#  'th': {'IsoList': {'232': '0.100000E+03'},
#   'MM': '0.232040E+03',
#   'Z': '90',
#   'rho': '0.117000E+02'},
#  'ti': {'IsoList': {'46': '0.800000E+01',
#    '47': '0.730000E+01',
#    '48': '0.738000E+02',
#    '49': '0.550000E+01',
#    '50': '0.540000E+01'},
#   'MM': '0.479000E+02',
#   'Z': '22',
#   'rho': '0.450000E+01'},
#  'tl': {'IsoList': {'203': '0.295200E+02', '205': '0.704800E+02'},
#   'MM': '0.204370E+03',
#   'Z': '81',
#   'rho': '0.118500E+02'},
#  'tm': {'IsoList': {'169': '0.100000E+03'},
#   'MM': '0.168934E+03',
#   'Z': '69',
#   'rho': '0.933000E+01'},
#  'u': {'IsoList': {'234': '0.550000E-02',
#    '235': '0.720000E+00',
#    '238': '0.992745E+02'},
#   'MM': '0.238029E+03',
#   'Z': '92',
#   'rho': '0.189000E+02'},
#  'v': {'IsoList': {'50': '0.250000E+00', '51': '0.997500E+02'},
#   'MM': '0.509415E+02',
#   'Z': '23',
#   'rho': '0.580000E+01'},
#  'w': {'IsoList': {'180': '0.120000E+00',
#    '182': '0.263000E+02',
#    '183': '0.142800E+02',
#    '184': '0.307000E+02',
#    '186': '0.286000E+02'},
#   'MM': '0.183850E+03',
#   'Z': '74',
#   'rho': '0.193000E+02'},
#  'xe': {'IsoList': {'124': '0.100000E+00',
#    '126': '0.900000E-01',
#    '128': '0.191000E+01',
#    '129': '0.264000E+02',
#    '130': '0.410000E+01',
#    '131': '0.212000E+02',
#    '132': '0.269000E+02',
#    '134': '0.104000E+02',
#    '136': '0.890000E+01'},
#   'MM': '0.131300E+03',
#   'Z': '54',
#   'rho': '0.589000E-02'},
#  'y': {'IsoList': {'89': '0.100000E+03'},
#   'MM': '0.889059E+02',
#   'Z': '39',
#   'rho': '0.450000E+01'},
#  'yb': {'IsoList': {'168': '0.130000E+00',
#    '170': '0.305000E+01',
#    '171': '0.143000E+02',
#    '172': '0.219000E+02',
#    '173': '0.161200E+02',
#    '174': '0.318000E+02',
#    '176': '0.127000E+02'},
#   'MM': '0.173040E+03',
#   'Z': '70',
#   'rho': '0.698000E+01'},
#  'zn': {'IsoList': {'64': '0.486000E+02',
#    '66': '0.279000E+02',
#    '67': '0.410000E+01',
#    '68': '0.188000E+02',
#    '70': '0.600000E+00'},
#   'MM': '0.653800E+02',
#   'Z': '30',
#   'rho': '0.714000E+01'},
#  'zr': {'IsoList': {'90': '0.514500E+02',
#    '91': '0.112200E+02',
#    '92': '0.171500E+02',
#    '94': '0.173800E+02',
#    '96': '0.280000E+01'},
#   'MM': '0.912200E+02',
#   'Z': '40',
#   'rho': '0.649000E+01'}}
